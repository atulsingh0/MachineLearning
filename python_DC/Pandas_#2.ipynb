# %%
# %matplotlib notebook

import pandas as pd
import matplotlib.pyplot as plt

# %%
# read ing the data
df = pd.read_table("dataset/plot.txt", sep="|")
df
# Out:
#    Month        AAPL        GOOG         IBM
# 0    Jan  117.160004  534.522445  153.309998
# 1    Feb  128.460007  558.402511  161.940002
# 2    Mar  124.430000  548.002468  160.500000
# 3    Apr  125.150002  537.340027  171.289993
# 4    May  130.279999  532.109985  169.649994
# 5    Jun  125.430000  520.510010  162.660004
# 6    Jul  121.300003  625.609985  161.990005
# 7    Aug  112.760002  618.250000  147.889999
# 8    Sep  110.300003  608.419983  144.970001
# 9    Oct  119.500000  710.809998  140.080002
# 10   Nov  118.300003  742.599976  139.419998
# 11   Dec  105.260002  758.880005  137.619995

# %%
# Create a list of y-axis column names: y_columns
y_columns = ['AAPL', 'IBM']

# Generate a line plot
df.plot(x='Month', y=y_columns)

# Add the title
plt.title('Monthly stock prices')

# Add the y-axis label
plt.ylabel('Price ($US)')

# Display the plot
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ```
# Generate a scatter plot with 'hp' on the x-axis and 'mpg' on the y-axis. Specify s=sizes.
# Add a title to the plot.
# Specify the x-axis and y-axis labels.
# ```

# %%
# reading another file
col = ['mpg', 'cylinders', 'displacement', 'hp', 'weight', 'acceleration','model year', 'origin', 'car name']
df = pd.read_table("dataset/auto-mpg.csv", names=col, sep=",")
len(df)
# Out:
# 406

# %%
  sizes=[51.12044694,   56.78387977,   49.15557238,   49.06977358, 49.52823321,   78.4595872 ,   78.93021696,   77.41479205, 81.52541106,   61.71459825,   52.85646225,   54.23007578,
         58.89427963,   39.65137852,   23.42587473,   33.41639502, 32.03903011,   27.8650165 ,   18.88972581,   14.0196956 , 29.72619722,   24.58549713,   23.48516821,   20.77938954,
         29.19459189,   88.67676838,   79.72987328,   79.94866084, 93.23005042,   18.88972581,   21.34122243,   20.6679223 , 28.88670381,   49.24144612,   46.14174741,   45.39631334,
         45.01218186,   73.76057586,   82.96880195,   71.84547684, 69.85320595,  102.22421043,   93.78252358,  110, 36.52889673,   24.14234281,   44.84805372,   41.02504618,
         20.51976563,   18.765772  ,   17.9095202 ,   17.75442285, 13.08832041,   10.83266174,   14.00441945,   15.91328975, 21.60597587,   18.8188451 ,   21.15311208,   24.14234281,
         20.63083317,   76.05635059,   80.05816704,   71.18975117, 70.98330444,   56.13992036,   89.36985382,   84.38736544, 82.6716892 ,   81.4149056 ,   22.60363518,   63.06844313,
         69.92143863,   76.76982089,   69.2066568 ,   35.81711267, 26.25184749,   36.94940537,   19.95069229,   23.88237331, 21.79608472,   26.1474042 ,   19.49759118,   18.36136808,
         69.98970461,   56.13992036,   66.21810474,   68.02351436, 59.39644014,  102.10046481,   82.96880195,   79.25686195, 74.74521151,   93.34830013,  102.05923292,   60.7883734 ,
         40.55589449,   44.7388015 ,   36.11079464,   37.9986264 , 35.11233175,   15.83199594,  103.96451839,  100.21241654, 90.18186347,   84.27493641,   32.38645967,   21.62494928,
         24.00218436,   23.56434276,   18.78345471,   22.21725537, 25.44271071,   21.36007926,   69.37650986,   76.19877818, 14.51292942,   19.38962134,   27.75740889,   34.24717407,
         48.10262495,   29.459795  ,   32.80584831,   55.89556844, 40.06360581,   35.03982309,   46.33599903,   15.83199594, 25.01226779,   14.03498009,   26.90404245,   59.52231336,
         54.92349014,   54.35035315,   71.39649768,   91.93424995, 82.70879915,   89.56285636,   75.45251972,   20.50128352, 16.04379287,   22.02531454,   11.32159874,   16.70430249]

# %%
# Generate a scatter plot
df.plot(kind='scatter', x='hp', y='mpg', s=sizes)

# Add the title
plt.title('Fuel efficiency vs Horse-power')

# Add the x-axis label
plt.xlabel('Horse-power')

# Add the y-axis label
plt.ylabel('Fuel efficiency (mpg)')

# Display the plot
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
# Make a list of the column names to be plotted: cols
cols = ['weight', 'mpg']

# Generate the box plots
df.plot(y=cols, kind='box', subplots=True )

# Display the plot
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
# Make a list of the column names to be plotted: cols
cols = ['weight', 'mpg']

# Generate the box plots
df[cols].plot(kind='box', subplots=True )

# Display the plot
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
# Pandas relies on the .hist() method to not only generate histograms, but also plots of PDFs and CDFs.
df = pd.read_csv("dataset/tips.csv")
len(df)
# Out:
# 244

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
print(df.count(), "\n\n",df.mean())
# Out:
# total_bill    244
# tip           244
# sex           244
# smoker        244
# day           244
# time          244
# size          244
# dtype: int64
#
#  total_bill    19.785943
# tip            2.998279
# size           2.569672
# dtype: float64

# %% [markdown]
# ### Statistical exploratory data analysis
